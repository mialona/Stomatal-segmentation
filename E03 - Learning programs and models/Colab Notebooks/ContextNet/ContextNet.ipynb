# %% [markdown]
# # ContextNet
# Instalación de la librería fast.ai (a continuación reiniciar el entorno de ejecución).

# %%
# !pip install fastai --upgrade

# %%
from fastai.basics import *
from fastai.vision import models
from fastai.vision.all import *
from fastai.metrics import *
from fastai.data.all import *
from fastai.callback import *

from fastai.learner import defaults, Learner

from pathlib import Path
import random

# %% [markdown]
# Descarga de la librería de arquitecturas.

# %%
# !wget https://www.dropbox.com/s/cmoblvx5icdifwl/architectures.zip?dl=1 -O architectures.zip
# !unzip architectures.zip

# %% [markdown]
# Descarga del dataset.

# %%
# !wget https://www.dropbox.com/s/p92cw15pleunmqe/dataset.zip?dl=1 -O dataset.zip
# !unzip dataset.zip

# %% [markdown]
# Conexión con Drive para el almacenaje de los modelos.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Rutas a los directorios del dataset.

# %%
path=Path('dataset/')
path_images = path/"Images"
path_labels = path/"Labels"
test_name = "test"

# %% [markdown]
# Función que dada la ruta de una imagen devuelve el path de su anotación.

# %%
def get_y_fn (x):
    return Path(str(x).replace("Images","Labels"))

# %% [markdown]
# Clases: Background y Stoma.

# %%
codes = np.loadtxt(path/'codes.txt', dtype=str)

# %% [markdown]
# Función que permite partir el dataset entre entrenamiento y test.

# %%
def ParentSplitter(x):
    return Path(x).parent.name==test_name

# %% [markdown]
# # Data augmentation
# Carga de la librería Albumentations.

# %%
from albumentations import (
    Compose,
    OneOf,
    ElasticTransform,
    GridDistortion, 
    OpticalDistortion,
    HorizontalFlip,
    Flip,
    Rotate,
    Transpose,
    CLAHE,
    ShiftScaleRotate
)

class SegmentationAlbumentationsTransform(ItemTransform):
    split_idx = 0
    
    def __init__(self, aug): 
        self.aug = aug
        
    def encodes(self, x):
        img,mask = x
        aug = self.aug(image=np.array(img), mask=np.array(mask))
        return PILImage.create(aug["image"]), PILMask.create(aug["mask"])

# %% [markdown]
# Transformación que aplica a las imagenes giros horizontales, rotaciones y una operación de distorsión.

# %%
transforms=Compose([HorizontalFlip(p=0.5),
                    Flip(p=0.5),
                    Rotate(p=0.40,limit=10)
                    ],p=1)

# %%
transformPipeline=SegmentationAlbumentationsTransform(transforms)

# %% [markdown]
# Transformación que no aplica cambios a las imagenes.

# %%
transforms2=Compose([],p=1)

# %%
transform2Pipeline=SegmentationAlbumentationsTransform(transforms2)

# %% [markdown]
# Transformación que cambia todos los píxeles con valor 255 a valor 1 en las máscaras.

# %%
class TargetMaskConvertTransform(ItemTransform):
    def __init__(self): 
        pass
    def encodes(self, x):
        img,mask = x
        
        #Convert to array
        mask = np.array(mask)
        
        mask[mask!=255]=0
        # Change 255 for 1
        mask[mask==255]=1
        
        
        # Back to PILMask
        mask = PILMask.create(mask)
        return img, mask

# %% [markdown]
# # Dataloaders
# DataBlock de entrenamiento con aumento de datos.

# %%
trainDB = DataBlock(blocks=(ImageBlock, MaskBlock(codes)),
                   get_items=partial(get_image_files,folders=['train']),
                   get_y=get_y_fn,
                   splitter=RandomSplitter(valid_pct=0.2),
                   item_tfms=[Resize((50,50)), TargetMaskConvertTransform(), transformPipeline],
                   batch_tfms=Normalize.from_stats(*imagenet_stats)
                  )

# %% [markdown]
# DataBlock de entrenamiento sin aumento de datos.

# %%
train2DB = DataBlock(blocks=(ImageBlock, MaskBlock(codes)),
                   get_items=partial(get_image_files,folders=['train']),
                   get_y=get_y_fn,
                   splitter=RandomSplitter(valid_pct=0.2),
                   item_tfms=[Resize((50,50)), TargetMaskConvertTransform(), transform2Pipeline],
                   batch_tfms=Normalize.from_stats(*imagenet_stats)
                  )

# %% [markdown]
# DataBlock de test.

# %%
testDB = DataBlock(blocks=(ImageBlock, MaskBlock(codes)),
                   get_items=partial(get_image_files,folders=['train','test']),
                   get_y=get_y_fn,
                   splitter=FuncSplitter(ParentSplitter),
                   item_tfms=[Resize((50,50)), TargetMaskConvertTransform(), transformPipeline],
                   batch_tfms=Normalize.from_stats(*imagenet_stats)
                  )

# %% [markdown]
# Creación de los dataloaders.

# %%
bs = 2
trainDLS = trainDB.dataloaders(path_images,bs=bs)
train2DLS = trainDB.dataloaders(path_images,bs=bs)
testDLS = testDB.dataloaders(path_images,bs=bs)

# %% [markdown]
# Prueba de la carga de datos.

# %%
trainDLS.show_batch(vmin=0,vmax=1,figsize=(12, 9))

# %% [markdown]
# # Modelos con aumento de datos
# Definición del modelo.

# %%
from architectures import ContextNet
model = ContextNet(nclass=2)

# %% [markdown]
# Creación del Learner con wd=1e-2 y definición del directorio de trabajo.

# %%
learn = Learner(dls=trainDLS, model=model, metrics=[Dice(), JaccardCoeff()], wd=1e-2)
learn.model_dir = "/content/drive/MyDrive/Colab Notebooks/ContextNet"

# %% [markdown]
# Freeze y elección de la tasa de aprendizaje.

# %%
learn.freeze()
learn.lr_find()
learn.recorder
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# Recorder

# %% [markdown]
# Entrenamiento del modelo usando EarlyStoppingCallback según el valid_loss (min_delta=0.0001 y patience=2).

# %%
name = "model_ContextNet_da_wd2"
learn.fit_one_cycle(100,slice(1e-5,1e-4),cbs=[
                                              EarlyStoppingCallback(monitor='valid_loss', min_delta=0.0001, patience=2),
                                              ShowGraphCallback(),
                                              SaveModelCallback(monitor='valid_loss', min_delta=0.0001, fname=name, every_epoch=False)])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>jaccard_coeff</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.355327</td>
#       <td>0.377017</td>
#       <td>0.908925</td>
#       <td>0.833055</td>
#       <td>05:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.342383</td>
#       <td>0.373400</td>
#       <td>0.902596</td>
#       <td>0.822483</td>
#       <td>05:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.331235</td>
#       <td>0.353686</td>
#       <td>0.908608</td>
#       <td>0.832522</td>
#       <td>05:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.312430</td>
#       <td>0.331064</td>
#       <td>0.913927</td>
#       <td>0.841498</td>
#       <td>05:03</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.296867</td>
#       <td>0.317874</td>
#       <td>0.917820</td>
#       <td>0.848121</td>
#       <td>05:02</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.314240</td>
#       <td>0.313867</td>
#       <td>0.916957</td>
#       <td>0.846649</td>
#       <td>05:02</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.279641</td>
#       <td>0.299135</td>
#       <td>0.921404</td>
#       <td>0.854262</td>
#       <td>05:03</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.273409</td>
#       <td>0.266470</td>
#       <td>0.931642</td>
#       <td>0.872032</td>
#       <td>05:03</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.275699</td>
#       <td>0.301844</td>
#       <td>0.918200</td>
#       <td>0.848771</td>
#       <td>05:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.253823</td>
#       <td>0.267144</td>
#       <td>0.931372</td>
#       <td>0.871558</td>
#       <td>05:00</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# Better model found at epoch 0 with valid_loss value: 0.37701740860939026.
# Better model found at epoch 1 with valid_loss value: 0.37340033054351807.
# Better model found at epoch 2 with valid_loss value: 0.35368612408638.
# Better model found at epoch 3 with valid_loss value: 0.3310639262199402.
# Better model found at epoch 4 with valid_loss value: 0.3178744614124298.
# Better model found at epoch 5 with valid_loss value: 0.313866525888443.
# Better model found at epoch 6 with valid_loss value: 0.2991354167461395.
# Better model found at epoch 7 with valid_loss value: 0.26647040247917175.
# No improvement since epoch 7: early stopping

# %% [markdown]
# Comprobación de los resultados obtenidos en el modelo almacenado.

# %%
learn.load("model_ContextNet_da_wd2")
learn.validate()
# Out:
# /usr/local/lib/python3.7/dist-packages/fastai/learner.py:56: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# (#3) [0.26647040247917175,0.9316419918936018,0.8720316455949841]

# %% [markdown]
# Unfreeze y elección de la tasa de aprendizaje.

# %%
learn.unfreeze()
learn.lr_find()
learn.recorder
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# Recorder

# %% [markdown]
# Entrenamiento del modelo usando EarlyStoppingCallback según el valid_loss (min_delta=0.0001 y patience=2).

# %%
name = "model_ContextNet_da_wd2_unfreeze"
learn.fit_one_cycle(100,slice(1e-5,1e-4),cbs=[
                                              EarlyStoppingCallback(monitor='valid_loss', min_delta=0.0001, patience=2),
                                              ShowGraphCallback(),
                                              SaveModelCallback(monitor='valid_loss', min_delta=0.0001, fname=name, every_epoch=False)])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>jaccard_coeff</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.260728</td>
#       <td>0.278275</td>
#       <td>0.928619</td>
#       <td>0.866750</td>
#       <td>05:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.275526</td>
#       <td>0.285916</td>
#       <td>0.926839</td>
#       <td>0.863653</td>
#       <td>05:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.272092</td>
#       <td>0.305427</td>
#       <td>0.918429</td>
#       <td>0.849162</td>
#       <td>05:02</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# Better model found at epoch 0 with valid_loss value: 0.2782745063304901.
# No improvement since epoch 0: early stopping

# %% [markdown]
# Comprobación de los resultados obtenidos en el modelo almacenado.

# %%
learn.load("model_ContextNet_da_wd2_unfreeze")
learn.validate()
# Out:
# /usr/local/lib/python3.7/dist-packages/fastai/learner.py:56: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# (#3) [0.2782745063304901,0.9286192928254953,0.8667500605592324]

# %% [markdown]
# ---
#
#
# Definición del modelo.

# %%
del model, learn
model = ContextNet(nclass=2)

# %% [markdown]
# Creación del Learner con wd=1e-1 y definición del directorio de trabajo.

# %%
learn = Learner(dls=trainDLS, model=model, metrics=[Dice(), JaccardCoeff()], wd=1e-1)
learn.model_dir = "/content/drive/MyDrive/Colab Notebooks/ContextNet"

# %% [markdown]
# Freeze y elección de la tasa de aprendizaje.

# %%
learn.freeze()
learn.lr_find()
learn.recorder
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# Recorder

# %% [markdown]
# Entrenamiento del modelo usando EarlyStoppingCallback según el valid_loss (min_delta=0.0001 y patience=2).

# %%
name = "model_ContextNet_da_wd1"
learn.fit_one_cycle(100,slice(1e-5,1e-4),cbs=[
                                              EarlyStoppingCallback(monitor='valid_loss', min_delta=0.0001, patience=2),
                                              ShowGraphCallback(),
                                              SaveModelCallback(monitor='valid_loss', min_delta=0.0001, fname=name, every_epoch=False)])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>jaccard_coeff</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.351491</td>
#       <td>0.367980</td>
#       <td>0.907019</td>
#       <td>0.829858</td>
#       <td>05:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.349928</td>
#       <td>0.353563</td>
#       <td>0.906220</td>
#       <td>0.828521</td>
#       <td>05:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.325347</td>
#       <td>0.357976</td>
#       <td>0.901638</td>
#       <td>0.820893</td>
#       <td>05:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.322343</td>
#       <td>0.358417</td>
#       <td>0.899215</td>
#       <td>0.816886</td>
#       <td>05:06</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# Better model found at epoch 0 with valid_loss value: 0.36797985434532166.
# Better model found at epoch 1 with valid_loss value: 0.35356318950653076.
# No improvement since epoch 1: early stopping

# %% [markdown]
# Comprobación de los resultados obtenidos en el modelo almacenado.

# %%
learn.load("model_ContextNet_da_wd1")
learn.validate()
# Out:
# /usr/local/lib/python3.7/dist-packages/fastai/learner.py:56: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# (#3) [0.35356318950653076,0.9062196533565954,0.8285206953458288]

# %% [markdown]
# Unfreeze y elección de la tasa de aprendizaje.

# %%
learn.unfreeze()
learn.lr_find()
learn.recorder
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# Recorder

# %% [markdown]
# Entrenamiento del modelo usando EarlyStoppingCallback según el valid_loss (min_delta=0.0001 y patience=2).

# %%
name = "model_ContextNet_da_wd1_unfreeze"
learn.fit_one_cycle(100,slice(1e-5,1e-4),cbs=[
                                              EarlyStoppingCallback(monitor='valid_loss', min_delta=0.0001, patience=2),
                                              ShowGraphCallback(),
                                              SaveModelCallback(monitor='valid_loss', min_delta=0.0001, fname=name, every_epoch=False)])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>jaccard_coeff</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.331973</td>
#       <td>0.354232</td>
#       <td>0.903922</td>
#       <td>0.824688</td>
#       <td>05:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.328228</td>
#       <td>0.359631</td>
#       <td>0.899550</td>
#       <td>0.817438</td>
#       <td>05:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.323216</td>
#       <td>0.346131</td>
#       <td>0.903817</td>
#       <td>0.824513</td>
#       <td>05:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.304584</td>
#       <td>0.337339</td>
#       <td>0.904789</td>
#       <td>0.826132</td>
#       <td>05:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.288501</td>
#       <td>0.336659</td>
#       <td>0.902260</td>
#       <td>0.821925</td>
#       <td>05:12</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.291237</td>
#       <td>0.322049</td>
#       <td>0.908539</td>
#       <td>0.832407</td>
#       <td>05:19</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.283038</td>
#       <td>0.300065</td>
#       <td>0.916257</td>
#       <td>0.845456</td>
#       <td>05:21</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.271821</td>
#       <td>0.289640</td>
#       <td>0.920866</td>
#       <td>0.853338</td>
#       <td>05:24</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.232149</td>
#       <td>0.289169</td>
#       <td>0.921981</td>
#       <td>0.855255</td>
#       <td>05:18</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.232735</td>
#       <td>0.289071</td>
#       <td>0.919064</td>
#       <td>0.850248</td>
#       <td>05:15</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.226057</td>
#       <td>0.273013</td>
#       <td>0.925598</td>
#       <td>0.861501</td>
#       <td>05:14</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.232785</td>
#       <td>0.241485</td>
#       <td>0.936495</td>
#       <td>0.880575</td>
#       <td>05:12</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.238164</td>
#       <td>0.230042</td>
#       <td>0.940986</td>
#       <td>0.888550</td>
#       <td>05:19</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.225782</td>
#       <td>0.238671</td>
#       <td>0.935358</td>
#       <td>0.878565</td>
#       <td>05:22</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.211281</td>
#       <td>0.250472</td>
#       <td>0.935390</td>
#       <td>0.878623</td>
#       <td>05:19</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# Better model found at epoch 0 with valid_loss value: 0.3542322516441345.
# Better model found at epoch 2 with valid_loss value: 0.3461313843727112.
# Better model found at epoch 3 with valid_loss value: 0.33733949065208435.
# Better model found at epoch 4 with valid_loss value: 0.3366594612598419.
# Better model found at epoch 5 with valid_loss value: 0.32204920053482056.
# Better model found at epoch 6 with valid_loss value: 0.30006512999534607.
# Better model found at epoch 7 with valid_loss value: 0.28964048624038696.
# Better model found at epoch 8 with valid_loss value: 0.2891692817211151.
# Better model found at epoch 10 with valid_loss value: 0.27301323413848877.
# Better model found at epoch 11 with valid_loss value: 0.24148467183113098.
# Better model found at epoch 12 with valid_loss value: 0.23004235327243805.
# No improvement since epoch 12: early stopping

# %% [markdown]
# Comprobación de los resultados obtenidos en el modelo almacenado.

# %%
learn.load("model_ContextNet_da_wd1_unfreeze")
learn.validate()
# Out:
# /usr/local/lib/python3.7/dist-packages/fastai/learner.py:56: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# (#3) [0.23004235327243805,0.9409864994453193,0.8885500505446415]

# %% [markdown]
# # Modelos sin aumento de datos
# Definición del modelo.

# %%
del model, learn
model = ContextNet(nclass=2)

# %% [markdown]
# Creación del Learner con wd=1e-2 y definición del directorio de trabajo.

# %%
learn = Learner(dls=train2DLS, model=model, metrics=[Dice(), JaccardCoeff()], wd=1e-2)
learn.model_dir = "/content/drive/MyDrive/Colab Notebooks/ContextNet"

# %% [markdown]
# Freeze y elección de la tasa de aprendizaje.

# %%
learn.freeze()
learn.lr_find()
learn.recorder
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# Recorder

# %% [markdown]
# Entrenamiento del modelo usando EarlyStoppingCallback según el valid_loss (min_delta=0.0001 y patience=2).

# %%
name = "model_ContextNet_wd2"
learn.fit_one_cycle(100,slice(1e-5,1e-4),cbs=[
                                              EarlyStoppingCallback(monitor='valid_loss', min_delta=0.0001, patience=2),
                                              ShowGraphCallback(),
                                              SaveModelCallback(monitor='valid_loss', min_delta=0.0001, fname=name, every_epoch=False)])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>jaccard_coeff</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.357412</td>
#       <td>0.369907</td>
#       <td>0.906594</td>
#       <td>0.829148</td>
#       <td>05:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.327925</td>
#       <td>0.354384</td>
#       <td>0.904253</td>
#       <td>0.825239</td>
#       <td>05:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.333226</td>
#       <td>0.350481</td>
#       <td>0.904069</td>
#       <td>0.824932</td>
#       <td>05:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.321102</td>
#       <td>0.328033</td>
#       <td>0.910900</td>
#       <td>0.836379</td>
#       <td>05:19</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.314960</td>
#       <td>0.327088</td>
#       <td>0.907400</td>
#       <td>0.830497</td>
#       <td>05:20</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.283281</td>
#       <td>0.324613</td>
#       <td>0.905722</td>
#       <td>0.827689</td>
#       <td>05:18</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.278808</td>
#       <td>0.292881</td>
#       <td>0.917595</td>
#       <td>0.847738</td>
#       <td>05:19</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.256050</td>
#       <td>0.278459</td>
#       <td>0.922621</td>
#       <td>0.856357</td>
#       <td>05:19</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.257245</td>
#       <td>0.254209</td>
#       <td>0.933177</td>
#       <td>0.874726</td>
#       <td>05:17</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.255832</td>
#       <td>0.252650</td>
#       <td>0.932335</td>
#       <td>0.873246</td>
#       <td>05:21</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.231764</td>
#       <td>0.245123</td>
#       <td>0.933525</td>
#       <td>0.875338</td>
#       <td>05:19</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.228855</td>
#       <td>0.233288</td>
#       <td>0.938390</td>
#       <td>0.883930</td>
#       <td>05:20</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.223740</td>
#       <td>0.230352</td>
#       <td>0.939708</td>
#       <td>0.886273</td>
#       <td>05:20</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.218954</td>
#       <td>0.257032</td>
#       <td>0.930986</td>
#       <td>0.870883</td>
#       <td>05:15</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.213514</td>
#       <td>0.228893</td>
#       <td>0.937773</td>
#       <td>0.882837</td>
#       <td>05:17</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.232468</td>
#       <td>0.215760</td>
#       <td>0.942666</td>
#       <td>0.891550</td>
#       <td>05:17</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.207832</td>
#       <td>0.224528</td>
#       <td>0.939579</td>
#       <td>0.886043</td>
#       <td>05:15</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.198152</td>
#       <td>0.220783</td>
#       <td>0.940558</td>
#       <td>0.887787</td>
#       <td>05:15</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# Better model found at epoch 0 with valid_loss value: 0.3699067234992981.
# Better model found at epoch 1 with valid_loss value: 0.35438433289527893.
# Better model found at epoch 2 with valid_loss value: 0.3504810035228729.
# Better model found at epoch 3 with valid_loss value: 0.3280332386493683.
# Better model found at epoch 4 with valid_loss value: 0.3270883560180664.
# Better model found at epoch 5 with valid_loss value: 0.32461318373680115.
# Better model found at epoch 6 with valid_loss value: 0.2928808331489563.
# Better model found at epoch 7 with valid_loss value: 0.2784588932991028.
# Better model found at epoch 8 with valid_loss value: 0.25420942902565.
# Better model found at epoch 9 with valid_loss value: 0.2526499927043915.
# Better model found at epoch 10 with valid_loss value: 0.245123028755188.
# Better model found at epoch 11 with valid_loss value: 0.2332884818315506.
# Better model found at epoch 12 with valid_loss value: 0.2303515076637268.
# Better model found at epoch 14 with valid_loss value: 0.2288934886455536.
# Better model found at epoch 15 with valid_loss value: 0.21575967967510223.
# No improvement since epoch 15: early stopping

# %% [markdown]
# Comprobación de los resultados obtenidos en el modelo almacenado.

# %%
learn.load("model_ContextNet_wd2")
learn.validate()
# Out:
# /usr/local/lib/python3.7/dist-packages/fastai/learner.py:56: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# (#3) [0.21575967967510223,0.942666250840251,0.8915503279729575]

# %% [markdown]
# Unfreeze y elección de la tasa de aprendizaje.

# %%
learn.unfreeze()
learn.lr_find()
learn.recorder
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# Recorder

# %% [markdown]
# Entrenamiento del modelo usando EarlyStoppingCallback según el valid_loss (min_delta=0.0001 y patience=2).

# %%
name = "model_ContextNet_wd2_unfreeze"
learn.fit_one_cycle(100,slice(1e-5,1e-4),cbs=[
                                              EarlyStoppingCallback(monitor='valid_loss', min_delta=0.0001, patience=2),
                                              ShowGraphCallback(),
                                              SaveModelCallback(monitor='valid_loss', min_delta=0.0001, fname=name, every_epoch=False)])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>jaccard_coeff</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.207853</td>
#       <td>0.219863</td>
#       <td>0.941255</td>
#       <td>0.889029</td>
#       <td>05:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.209637</td>
#       <td>0.223441</td>
#       <td>0.939341</td>
#       <td>0.885621</td>
#       <td>05:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.216438</td>
#       <td>0.226265</td>
#       <td>0.937958</td>
#       <td>0.883165</td>
#       <td>05:12</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# Better model found at epoch 0 with valid_loss value: 0.21986301243305206.
# No improvement since epoch 0: early stopping

# %% [markdown]
# Comprobación de los resultados obtenidos en el modelo almacenado.

# %%
learn.load("model_ContextNet_wd2_unfreeze")
learn.validate()
# Out:
# /usr/local/lib/python3.7/dist-packages/fastai/learner.py:56: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# (#3) [0.21986301243305206,0.9412551750766397,0.8890293042469177]

# %% [markdown]
# ---
#
#
# Definición del modelo.

# %%
del model, learn
model = ContextNet(nclass=2)

# %% [markdown]
# Creación del Learner con wd=1e-1 y definición del directorio de trabajo.

# %%
learn = Learner(dls=train2DLS, model=model, metrics=[Dice(), JaccardCoeff()], wd=1e-1)
learn.model_dir = "/content/drive/MyDrive/Colab Notebooks/ContextNet"

# %% [markdown]
# Freeze y elección de la tasa de aprendizaje.

# %%
learn.freeze()
learn.lr_find()
learn.recorder
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# Recorder

# %% [markdown]
# Entrenamiento del modelo usando EarlyStoppingCallback según el valid_loss (min_delta=0.0001 y patience=2).

# %%
name = "model_ContextNet_wd1"
learn.fit_one_cycle(100,slice(1e-5,1e-4),cbs=[
                                              EarlyStoppingCallback(monitor='valid_loss', min_delta=0.0001, patience=2),
                                              ShowGraphCallback(),
                                              SaveModelCallback(monitor='valid_loss', min_delta=0.0001, fname=name, every_epoch=False)])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>jaccard_coeff</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.355639</td>
#       <td>0.370934</td>
#       <td>0.906219</td>
#       <td>0.828520</td>
#       <td>05:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.349876</td>
#       <td>0.358959</td>
#       <td>0.903666</td>
#       <td>0.824261</td>
#       <td>05:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.324028</td>
#       <td>0.350284</td>
#       <td>0.907127</td>
#       <td>0.830039</td>
#       <td>05:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.320867</td>
#       <td>0.345640</td>
#       <td>0.905180</td>
#       <td>0.826784</td>
#       <td>05:04</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.294721</td>
#       <td>0.328896</td>
#       <td>0.911261</td>
#       <td>0.836987</td>
#       <td>05:04</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.299948</td>
#       <td>0.315521</td>
#       <td>0.911873</td>
#       <td>0.838020</td>
#       <td>05:02</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.290452</td>
#       <td>0.312913</td>
#       <td>0.911438</td>
#       <td>0.837287</td>
#       <td>05:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.256279</td>
#       <td>0.271432</td>
#       <td>0.928027</td>
#       <td>0.865719</td>
#       <td>05:01</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.248931</td>
#       <td>0.277515</td>
#       <td>0.925066</td>
#       <td>0.860579</td>
#       <td>05:01</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.241322</td>
#       <td>0.262325</td>
#       <td>0.931696</td>
#       <td>0.872126</td>
#       <td>05:00</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.244268</td>
#       <td>0.263505</td>
#       <td>0.930667</td>
#       <td>0.870325</td>
#       <td>05:00</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.218190</td>
#       <td>0.240017</td>
#       <td>0.936623</td>
#       <td>0.880800</td>
#       <td>04:59</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.229391</td>
#       <td>0.247537</td>
#       <td>0.934489</td>
#       <td>0.877033</td>
#       <td>05:00</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.232538</td>
#       <td>0.219804</td>
#       <td>0.942617</td>
#       <td>0.891463</td>
#       <td>04:59</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.231417</td>
#       <td>0.217701</td>
#       <td>0.943554</td>
#       <td>0.893140</td>
#       <td>04:59</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.206996</td>
#       <td>0.211441</td>
#       <td>0.946007</td>
#       <td>0.897547</td>
#       <td>04:59</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.257373</td>
#       <td>0.208406</td>
#       <td>0.945439</td>
#       <td>0.896524</td>
#       <td>04:59</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.198518</td>
#       <td>0.207613</td>
#       <td>0.945958</td>
#       <td>0.897458</td>
#       <td>05:01</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.211987</td>
#       <td>0.206418</td>
#       <td>0.944893</td>
#       <td>0.895542</td>
#       <td>05:01</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.211676</td>
#       <td>0.207329</td>
#       <td>0.945729</td>
#       <td>0.897045</td>
#       <td>05:00</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.200332</td>
#       <td>0.201547</td>
#       <td>0.947889</td>
#       <td>0.900941</td>
#       <td>05:02</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.186807</td>
#       <td>0.204320</td>
#       <td>0.946904</td>
#       <td>0.899161</td>
#       <td>05:01</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.210987</td>
#       <td>0.197898</td>
#       <td>0.947951</td>
#       <td>0.901052</td>
#       <td>05:03</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.203788</td>
#       <td>0.206313</td>
#       <td>0.945164</td>
#       <td>0.896029</td>
#       <td>05:03</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.197451</td>
#       <td>0.209325</td>
#       <td>0.943737</td>
#       <td>0.893468</td>
#       <td>05:03</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# Better model found at epoch 0 with valid_loss value: 0.37093445658683777.
# Better model found at epoch 1 with valid_loss value: 0.35895901918411255.
# Better model found at epoch 2 with valid_loss value: 0.3502841889858246.
# Better model found at epoch 3 with valid_loss value: 0.3456399142742157.
# Better model found at epoch 4 with valid_loss value: 0.32889631390571594.
# Better model found at epoch 5 with valid_loss value: 0.31552135944366455.
# Better model found at epoch 6 with valid_loss value: 0.31291258335113525.
# Better model found at epoch 7 with valid_loss value: 0.2714315950870514.
# Better model found at epoch 9 with valid_loss value: 0.2623254358768463.
# Better model found at epoch 11 with valid_loss value: 0.240016907453537.
# Better model found at epoch 13 with valid_loss value: 0.21980437636375427.
# Better model found at epoch 14 with valid_loss value: 0.21770085394382477.
# Better model found at epoch 15 with valid_loss value: 0.21144059300422668.
# Better model found at epoch 16 with valid_loss value: 0.20840564370155334.
# Better model found at epoch 17 with valid_loss value: 0.20761331915855408.
# Better model found at epoch 18 with valid_loss value: 0.20641764998435974.
# Better model found at epoch 20 with valid_loss value: 0.20154717564582825.
# Better model found at epoch 22 with valid_loss value: 0.1978975385427475.
# No improvement since epoch 22: early stopping

# %% [markdown]
# Comprobación de los resultados obtenidos en el modelo almacenado.

# %%
learn.load("model_ContextNet_wd1")
learn.validate()
# Out:
# /usr/local/lib/python3.7/dist-packages/fastai/learner.py:56: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# (#3) [0.1978975385427475,0.9479509915047775,0.901052121954528]

# %% [markdown]
# Unfreeze y elección de la tasa de aprendizaje.

# %%
learn.unfreeze()
learn.lr_find()
learn.recorder
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# Recorder

# %% [markdown]
# Entrenamiento del modelo usando EarlyStoppingCallback según el valid_loss (min_delta=0.0001 y patience=2).

# %%
name = "model_ContextNet_wd1_unfreeze"
learn.fit_one_cycle(100,slice(1e-5,1e-4),cbs=[
                                              EarlyStoppingCallback(monitor='valid_loss', min_delta=0.0001, patience=2),
                                              ShowGraphCallback(),
                                              SaveModelCallback(monitor='valid_loss', min_delta=0.0001, fname=name, every_epoch=False)])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>dice</th>
#       <th>jaccard_coeff</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.211716</td>
#       <td>0.194985</td>
#       <td>0.948684</td>
#       <td>0.902378</td>
#       <td>05:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.217384</td>
#       <td>0.195230</td>
#       <td>0.948523</td>
#       <td>0.902086</td>
#       <td>05:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.191260</td>
#       <td>0.198708</td>
#       <td>0.948195</td>
#       <td>0.901493</td>
#       <td>04:59</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# Better model found at epoch 0 with valid_loss value: 0.19498470425605774.
# No improvement since epoch 0: early stopping

# %% [markdown]
# Comprobación de los resultados obtenidos en el modelo almacenado.

# %%
learn.load("model_ContextNet_wd1_unfreeze")
learn.validate()
# Out:
# /usr/local/lib/python3.7/dist-packages/fastai/learner.py:56: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# (#3) [0.19498470425605774,0.9486840990632059,0.9023777707707682]

# %% [markdown]
# # Evaluación de resultados
# ## Modelos con aumento de datos
# Carga del primer modelo en la CPU.

# %%
learn.load("model_ContextNet_da_wd2")
aux=learn.model
aux=aux.cpu()

# %% [markdown]
# Asignación del dataloader de test y validación.

# %%
learn.dls = testDLS
learn.validate()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# (#3) [0.251142680644989,0.9361289246357328,0.8799270384479663]

# %% [markdown]
# Comparación de resultado buscado contra resultado obtenido.

# %%
learn.show_results(vmin=0,vmax=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "

# %% [markdown]
# Carga del segundo modelo en la CPU.

# %%
learn.load("model_ContextNet_da_wd2_unfreeze")
aux=learn.model
aux=aux.cpu()

# %% [markdown]
# Asignación del dataloader de test y validación.

# %%
learn.dls = testDLS
learn.validate()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# (#3) [0.2625829577445984,0.9330408313644764,0.8744859773384691]

# %% [markdown]
# Comparación de resultado buscado contra resultado obtenido.

# %%
learn.show_results(vmin=0,vmax=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "

# %% [markdown]
# ---
#
#
# Carga del tercer modelo en la CPU.

# %%
learn.load("model_ContextNet_da_wd1")
aux=learn.model
aux=aux.cpu()

# %% [markdown]
# Asignación del dataloader de test y validación.

# %%
learn.dls = testDLS
learn.validate()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# (#3) [0.344430536031723,0.9111959035128927,0.8368777325992384]

# %% [markdown]
# Comparación de resultado buscado contra resultado obtenido.

# %%
learn.show_results(vmin=0,vmax=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "

# %% [markdown]
# Carga del cuarto modelo en la CPU.

# %%
learn.load("model_ContextNet_da_wd1_unfreeze")
aux=learn.model
aux=aux.cpu()

# %% [markdown]
# Asignación del dataloader de test y validación.

# %%
learn.dls = testDLS
learn.validate()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# (#3) [0.20760931074619293,0.9485239911238724,0.9020880962730707]

# %% [markdown]
# Comparación de resultado buscado contra resultado obtenido.

# %%
learn.show_results(vmin=0,vmax=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "

# %% [markdown]
# ## Modelos sin aumento de datos
# Carga del primer modelo en la CPU.

# %%
learn.load("model_ContextNet_wd2")
aux=learn.model
aux=aux.cpu()

# %% [markdown]
# Asignación del dataloader de test y validación.

# %%
learn.dls = testDLS
learn.validate()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# (#3) [0.19618646800518036,0.949075984657139,0.9030871602524999]

# %% [markdown]
# Comparación de resultado buscado contra resultado obtenido.

# %%
learn.show_results(vmin=0,vmax=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "

# %% [markdown]
# Carga del segundo modelo en la CPU.

# %%
learn.load("model_ContextNet_wd2_unfreeze")
aux=learn.model
aux=aux.cpu()

# %% [markdown]
# Asignación del dataloader de test y validación.

# %%
learn.dls = testDLS
learn.validate()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# (#3) [0.2001197189092636,0.9477878639443793,0.9007573962198423]

# %% [markdown]
# Comparación de resultado buscado contra resultado obtenido.

# %%
learn.show_results(vmin=0,vmax=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "

# %% [markdown]
# ---
#
#
# Carga del tercer modelo en la CPU.

# %%
learn.load("model_ContextNet_wd1")
aux=learn.model
aux=aux.cpu()

# %% [markdown]
# Asignación del dataloader de test y validación.

# %%
learn.dls = testDLS
learn.validate()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# (#3) [0.18122127652168274,0.9529930322138812,0.9102069628332763]

# %% [markdown]
# Comparación de resultado buscado contra resultado obtenido.

# %%
learn.show_results(vmin=0,vmax=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "

# %% [markdown]
# Carga del cuarto modelo en la CPU.

# %%
learn.load("model_ContextNet_wd1_unfreeze")
aux=learn.model
aux=aux.cpu()

# %% [markdown]
# Asignación del dataloader de test y validación.

# %%
learn.dls = testDLS
learn.validate()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# (#3) [0.1795465499162674,0.9533370930142627,0.9108348892956936]

# %% [markdown]
# Comparación de resultado buscado contra resultado obtenido.

# %%
learn.show_results(vmin=0,vmax=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "

# %% [markdown]
# # Exportación del mejor modelo
# Carga del modelo en la CPU.

# %%
learn.load("model_ContextNet_wd1_unfreeze")
learn.dls = testDLS
learn.validate()
# Out:
# /usr/local/lib/python3.7/dist-packages/fastai/learner.py:56: UserWarning: Saved filed doesn't contain an optimizer state.
#   elif with_opt: warn("Saved filed doesn't contain an optimizer state.")
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3503: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   "The default behavior for interpolate/upsample with float scale_factor changed "
# (#3) [0.1795465648174286,0.9533370930142627,0.9108348892956936]

# %%
aux=learn.model
aux=aux.cpu()

# %% [markdown]
# Exportación del modelo mediante torch.jit.trace.

# %%
import torchvision.transforms as transforms
img = PILImage.create(path_images/'train/1D2_0.png')
transformer=transforms.Compose([transforms.Resize((50,50)),
                                transforms.ToTensor(),
                                transforms.Normalize(
                                                    [0.485, 0.456, 0.406],
                                                    [0.229, 0.224, 0.225])])
img=transformer(img).unsqueeze(0)
img=img.cpu()

traced_cell=torch.jit.trace(aux, (img))
traced_cell.save("/content/drive/MyDrive/Colab Notebooks/ContextNet/model_ContextNet.pkl")
